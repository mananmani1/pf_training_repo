# %% [markdown]
#                  **____________Video Object Detection by Yolo4_______________**

# %% [markdown]
# #### Import the Required Dependencies

# %%
import cv2
import numpy as np

# %% [markdown]
# ### Loading weights and configuration file for yolov4
# 1. **'modelConfiguration' specifies the configuration file (yolov4-tiny.cfg)** that contains the architecture of the model, including the number of layers, filters, and other parameters.
# 2. **'modelWeights' specifies the pre-trained weights file (yolov4-tiny.weights)** that contains the learned parameters of the model.

# %%
#read the wieghts and cfg file openCv , readNet function automatically detects an origin framework of a 
#trained model(readNetFromCaffe, readNetFromTensorflow, readNetFromTorch, or readNetFromDarknet).
net = cv2.dnn.readNet(r"C:\Users\Madina Computers\Documents\object_detection\dnn_model\yolov4-tiny.weights",\
                      r"C:\Users\Madina Computers\Documents\object_detection\dnn_model\yolov4-tiny.cfg")
model = cv2.dnn_DetectionModel(net)
model.setInputParams(size = (320,320),scale = 1/255)

# %% [markdown]
# #### Read the file that contain the name of different classes(objects name)

# %%
classes = []
with open(r"C:\Users\Madina Computers\Documents\object_detection\dnn_model\classes.txt","r") as file_object:
    for class_name in file_object.readlines():
        class_name = class_name.strip()
        classes.append(class_name)
print(classes)
# Out:
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %% [markdown]
# ##### Read the video file and also set the dimension of video frame

# %%
cap = cv2.VideoCapture(r"C:\Users\Madina Computers\Documents\object_detection\video.mp4")
# setting the dimension
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)
# Out:
# False

# %% [markdown]
# #### Draw the bbox and file name on video's objects

# %%
#as long as frame in the model
while True:
    #get frames
    ret,frame = cap.read()
    #get the bbox etc
    (class_ids, scores, bboxes) = model.detect(frame)
    for class_id, score, bbox in zip(class_ids, scores, bboxes):
        (x, y, w, h) = bbox
        #blue bbox
        cv2.rectangle(frame,(x,y),(x + w,y + h),(200,10,50),3)
        class_name = classes[class_id]
        #blue text
        cv2.putText(frame, (class_name),(x,y-10),cv2.FONT_HERSHEY_PLAIN,2,(200,10,50),2)
        cv2.rectangle(frame,(x,y),(x+w,y+h),(200,10,50),3)
    print('classs',class_ids)
    print('scores',scores)
    print('bboxes',bboxes) 
    

    cv2.imshow("Frame",frame)    
    key = cv2.waitKey(10)
    
    if key == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [0]
# scores [0.5037618]
# bboxes [[583 249  23  36]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.79894936]
# bboxes [[308 269  97  68]]
# classs [2]
# scores [0.84822226]
# bboxes [[295 264  98  61]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.5400053]
# bboxes [[275 244  82  57]]
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.53284246]
# bboxes [[263 234  72  53]]
# classs [2]
# scores [0.7109483]
# bboxes [[259 229  70  50]]
# classs [2 2]
# scores [0.5546737  0.58708954]
# bboxes [[249 226  73  49]
#  [256 224  68  49]]
# classs [2]
# scores [0.5106835]
# bboxes [[246 217  71  50]]
# classs [2]
# scores [0.8093151]
# bboxes [[240 216  66  46]]
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.50386477]
# bboxes [[237 213  59  38]]
# classs [2 2]
# scores [0.6393552 0.6021438]
# bboxes [[235 204  53  44]
#  [230 206  59  41]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.61997396]
# bboxes [[311 150  31  26]]
# classs [2]
# scores [0.5485606]
# bboxes [[311 151  31  27]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.6111799]
# bboxes [[321 158  37  24]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.56613404]
# bboxes [[338 166  32  25]]
# classs [2]
# scores [0.62700874]
# bboxes [[341 166  31  25]]
# classs [2]
# scores [0.78495467]
# bboxes [[342 166  33  26]]
# classs [7]
# scores [0.5355344]
# bboxes [[343 168  34  27]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.70798695]
# bboxes [[353 171  37  26]]
# classs [2]
# scores [0.5127227]
# bboxes [[355 174  37  25]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.52812684]
# bboxes [[367 177  39  27]]
# classs [2]
# scores [0.67575353]
# bboxes [[368 176  38  28]]
# classs [2]
# scores [0.75555587]
# bboxes [[375 184  35  25]]
# classs [2]
# scores [0.8473977]
# bboxes [[375 183  39  27]]
# classs [2]
# scores [0.8327732]
# bboxes [[377 182  41  30]]
# classs [2]
# scores [0.70725596]
# bboxes [[380 185  40  29]]
# classs [2]
# scores [0.6367391]
# bboxes [[382 188  43  27]]
# classs [2]
# scores [0.6752239]
# bboxes [[388 188  41  27]]
# classs [2]
# scores [0.7141511]
# bboxes [[391 188  41  29]]
# classs [2 2]
# scores [0.5636509 0.7487304]
# bboxes [[393 188  40  30]
#  [400 192  36  27]]
# classs [2 2]
# scores [0.5008073 0.836197 ]
# bboxes [[394 189  41  30]
#  [399 191  38  28]]
# classs [2]
# scores [0.92052853]
# bboxes [[399 190  42  30]]
# classs [2]
# scores [0.85955435]
# bboxes [[401 192  45  31]]
# classs [2]
# scores [0.76891154]
# bboxes [[404 193  46  29]]
# classs [2 2]
# scores [0.68548435 0.74770695]
# bboxes [[406 195  46  29]
#  [410 198  45  29]]
# classs [2]
# scores [0.75331765]
# bboxes [[411 199  48  31]]
# classs [7]
# scores [0.729012]
# bboxes [[411 199  55  33]]
# classs [7]
# scores [0.61653453]
# bboxes [[410 199  60  34]]
# classs [2]
# scores [0.69060755]
# bboxes [[431 204  41  28]]
# classs [2 2]
# scores [0.5692557  0.78829336]
# bboxes [[418 199  52  37]
#  [430 203  44  30]]
# classs [2]
# scores [0.83444613]
# bboxes [[433 205  45  30]]
# classs [2]
# scores [0.76527464]
# bboxes [[434 204  46  32]]
# classs [2 2]
# scores [0.686048   0.55200887]
# bboxes [[434 205  52  34]
#  [241 301 109  51]]
# classs [2]
# scores [0.6785172]
# bboxes [[443 207  50  34]]
# classs [2 2]
# scores [0.72697693 0.52590907]
# bboxes [[442 209  54  33]
#  [453 215  45  30]]
# classs [2]
# scores [0.6754945]
# bboxes [[444 206  52  36]]
# classs [2 2 2]
# scores [0.57573843 0.5361111  0.90051395]
# bboxes [[445 209  56  35]
#  [462 215  40  33]
#  [214 276 100  68]]
# classs [2 2 2]
# scores [0.6248624 0.8057713 0.7178031]
# bboxes [[450 213  54  37]
#  [462 217  42  32]
#  [214 269  89  69]]
# classs [5 2 2]
# scores [0.5288531  0.85731936 0.7590473 ]
# bboxes [[109 103 239 240]
#  [468 222  44  29]
#  [207 260  90  68]]
# classs [5 2 2]
# scores [0.6261644 0.8936869 0.7364651]
# bboxes [[112 101 214 236]
#  [466 219  53  32]
#  [205 258  85  61]]
# classs [2 2]
# scores [0.7420075  0.61352617]
# bboxes [[464 217  59  36]
#  [459 213  64  43]]
# classs [2 2]
# scores [0.8088844 0.5013979]
# bboxes [[470 218  56  35]
#  [457 214  71  42]]
# classs [2 2]
# scores [0.668742   0.75873846]
# bboxes [[473 218  52  37]
#  [192 244  79  57]]
# classs [2]
# scores [0.57618797]
# bboxes [[479 219  47  39]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.6237964]
# bboxes [[532 245  35  27]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.52871037]
# bboxes [[523 232  63  51]]
# classs [2]
# scores [0.6072087]
# bboxes [[526 235  69  50]]
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.54340774]
# bboxes [[528 243  80  46]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.50762975]
# bboxes [[542 245  81  47]]
# classs [2]
# scores [0.5936806]
# bboxes [[542 248  86  48]]
# classs [2]
# scores [0.6824988]
# bboxes [[543 250  91  49]]
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.6546328]
# bboxes [[552 251  87  50]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.56116134]
# bboxes [[326 293 100  58]]
# classs [2 2 2]
# scores [0.5891109  0.58142793 0.52666545]
# bboxes [[612 263  28  48]
#  [321 282  96  65]
#  [321 289  93  59]]
# classs [2]
# scores [0.92990214]
# bboxes [[318 286  82  54]]
# classs [2 2]
# scores [0.78491634 0.5266261 ]
# bboxes [[301 274  92  56]
#  [315 277  76  53]]
# classs [2 2]
# scores [0.820594   0.50848955]
# bboxes [[297 269  88  55]
#  [299 274  82  51]]
# classs [2]
# scores [0.9277101]
# bboxes [[291 266  78  49]]
# classs [2]
# scores [0.73129827]
# bboxes [[292 261  65  47]]
# classs [2 2]
# scores [0.742426   0.61111313]
# bboxes [[276 252  80  50]
#  [289 254  64  46]]
# classs [2]
# scores [0.760861]
# bboxes [[272 249  72  47]]
# classs [2 2]
# scores [0.5050269 0.7085676]
# bboxes [[268 232  66  57]
#  [270 243  65  47]]
# classs [2]
# scores [0.8120475]
# bboxes [[264 235  61  51]]
# classs [2 2]
# scores [0.8118637 0.804075 ]
# bboxes [[267 236  56  42]
#  [262 232  60  45]]
# classs [2 2]
# scores [0.54771334 0.5801708 ]
# bboxes [[253 229  62  46]
#  [260 229  58  44]]
# classs [2 2]
# scores [0.736263   0.63785994]
# bboxes [[251 228  64  41]
#  [248 228  66  41]]
# classs [2 2]
# scores [0.7737159  0.55357176]
# bboxes [[254 222  50  43]
#  [252 220  53  45]]
# classs [2]
# scores [0.8391783]
# bboxes [[243 220  54  39]]
# classs [2]
# scores [0.6990135]
# bboxes [[243 217  48  37]]
# classs [2]
# scores [0.8660753]
# bboxes [[242 214  45  36]]
# classs [2 2]
# scores [0.7225967 0.6139668]
# bboxes [[240 208  45  36]
#  [240 213  43  35]]
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.60356206]
# bboxes [[227 204  49  36]]
# classs [2]
# scores [0.60371363]
# bboxes [[224 202  44  33]]
# classs [2]
# scores [0.64619523]
# bboxes [[224 199  40  33]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.52409023]
# bboxes [[212 191  40  28]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.53852516]
# bboxes [[278 269 100  69]]
# classs [2]
# scores [0.71676195]
# bboxes [[265 262 100  67]]
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.50927305]
# bboxes [[255 251  89  58]]
# classs [2]
# scores [0.72724485]
# bboxes [[253 248  77  55]]
# classs [6 2]
# scores [0.559307  0.7029861]
# bboxes [[111 106 238 235]
#  [245 243  77  51]]
# classs [2]
# scores [0.75257564]
# bboxes [[235 235  81  52]]
# classs [2]
# scores [0.84430164]
# bboxes [[235 231  69  51]]
# classs [2]
# scores [0.85983133]
# bboxes [[227 225  71  48]]
# classs [2]
# scores [0.62538093]
# bboxes [[226 223  62  45]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [7]
# scores [0.59425974]
# bboxes [[205 201  49  37]]
# classs [2]
# scores [0.5918563]
# bboxes [[204 200  47  33]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.6006981]
# bboxes [[191 191  47  31]]
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.61057913]
# bboxes [[188 184  42  31]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [7]
# scores [0.51446134]
# bboxes [[286 127  42  36]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [5]
# scores [0.50018746]
# bboxes [[273 123  71  48]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [6]
# scores [0.5443313]
# bboxes [[276 123  71  49]]
# classs [6]
# scores [0.51850545]
# bboxes [[277 123  70  50]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [7]
# scores [0.58102715]
# bboxes [[294 135  76  49]]
# classs [7]
# scores [0.5273548]
# bboxes [[294 134  78  50]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [6]
# scores [0.56964433]
# bboxes [[235 115 185  82]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [2]
# scores [0.7330172]
# bboxes [[403 185  35  29]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [7]
# scores [0.5108072]
# bboxes [[411 189  42  30]]
# classs ()
# scores ()
# bboxes ()
# classs [6]
# scores [0.5281021]
# bboxes [[192  89 304 146]]
# classs [6]
# scores [0.6420614]
# bboxes [[198  90 295 147]]
# classs [6]
# scores [0.6307613]
# bboxes [[200  90 287 147]]
# classs [6]
# scores [0.65271586]
# bboxes [[200  89 283 151]]
# classs [2]
# scores [0.5671286]
# bboxes [[441 201  40  30]]
# classs [6]
# scores [0.71155506]
# bboxes [[193  91 307 151]]
# classs [6 2]
# scores [0.6827295  0.51100177]
# bboxes [[194  95 313 145]
#  [449 200  44  34]]
# classs ()
# scores ()
# bboxes ()
# classs [6]
# scores [0.6908775]
# bboxes [[329 159 182  82]]
# classs ()
# scores ()
# bboxes ()
# classs [6]
# scores [0.5750935]
# bboxes [[187  90 344 157]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [6]
# scores [0.62679523]
# bboxes [[238 103 314 163]]
# classs [6]
# scores [0.56650066]
# bboxes [[377 167 163  83]]
# classs ()
# scores ()
# bboxes ()
# classs [6]
# scores [0.686475]
# bboxes [[228 103 336 165]]
# classs [6]
# scores [0.5673806]
# bboxes [[235 103 324 169]]
# classs [2]
# scores [0.5263249]
# bboxes [[535 231  39  39]]
# classs [6 2]
# scores [0.51132584 0.5280695 ]
# bboxes [[393 171 160  95]
#  [536 234  46  36]]
# classs [6]
# scores [0.604223]
# bboxes [[395 177 178  88]]
# classs [6 6 6]
# scores [0.51027757 0.6574196  0.52441436]
# bboxes [[224  98 375 193]
#  [399 174 199  98]
#  [410 175 185  96]]
# classs [6 6]
# scores [0.8153963 0.5381414]
# bboxes [[404 177 195 101]
#  [412 177 184  97]]
# classs [5]
# scores [0.51912224]
# bboxes [[317 149  97  73]]
# classs [5]
# scores [0.539832]
# bboxes [[317 149 103  72]]
# classs [5 6 5]
# scores [0.6635211  0.67303526 0.6536831 ]
# bboxes [[306 138 128  87]
#  [421 183 211 113]
#  [315 146 113  80]]
# classs [5]
# scores [0.5167548]
# bboxes [[316 147 120  82]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()
# classs [6 7 5]
# scores [0.6467167  0.54371107 0.54088193]
# bboxes [[320 154 142  87]
#  [460 196 180 115]
#  [328 153 124  85]]
# classs [5 5]
# scores [0.8211609  0.91391313]
# bboxes [[326 158 139  86]
#  [331 154 128  86]]
# classs [5 5]
# scores [0.8708792 0.8599827]
# bboxes [[324 160 142  87]
#  [337 156 131  87]]
# classs [5 5]
# scores [0.7605838  0.91061383]
# bboxes [[323 159 147  88]
#  [339 158 130  86]]
# classs [5 5]
# scores [0.9250197 0.9562262]
# bboxes [[327 161 145  87]
#  [342 161 133  87]]
# classs [5 5]
# scores [0.7496737  0.77373064]
# bboxes [[328 159 148  88]
#  [346 159 129  90]]
# classs [5 5 5]
# scores [0.87630206 0.70229805 0.7199081 ]
# bboxes [[334 161 145  91]
#  [346 162 132  90]
#  [355 163 126  89]]
# classs [5 5]
# scores [0.6397258  0.58479375]
# bboxes [[328 163 161  89]
#  [354 163 130  91]]
# classs [5 5]
# scores [0.616938   0.61990535]
# bboxes [[328 159 172  97]
#  [353 163 137  91]]
# classs [5 5 5]
# scores [0.6129285 0.740294  0.7058362]
# bboxes [[353 165 149  96]
#  [353 164 143  91]
#  [357 165 141  96]]
# classs [5 5 5]
# scores [0.7503146 0.6194806 0.8367549]
# bboxes [[360 165 151 100]
#  [352 160 156  98]
#  [356 169 153  93]]
# classs [5 5 5 5]
# scores [0.5589515  0.93128425 0.5338577  0.8700952 ]
# bboxes [[351 162 165  94]
#  [364 168 153  94]
#  [356 163 158  93]
#  [361 168 152  95]]
# classs [5 5 5]
# scores [0.89493823 0.6436479  0.8664727 ]
# bboxes [[362 167 162  98]
#  [376 170 149  99]
#  [364 168 154 100]]
# classs [5 5 5]
# scores [0.5677133  0.63077855 0.67350185]
# bboxes [[363 167 162 105]
#  [363 169 161 103]
#  [373 170 156 104]]
# classs [5 5 5]
# scores [0.6298627  0.59252894 0.512711  ]
# bboxes [[362 163 164 114]
#  [364 169 159 105]
#  [375 169 153 106]]
# classs [5 5]
# scores [0.561837   0.55845374]
# bboxes [[376 173 153 111]
#  [375 171 156 106]]
# classs [5 5]
# scores [0.6725331 0.7422201]
# bboxes [[377 172 154 107]
#  [374 171 162 107]]
# classs [5 5 5]
# scores [0.88217074 0.8692444  0.5844732 ]
# bboxes [[379 172 156 110]
#  [380 169 164 110]
#  [379 178 161 108]]
# classs [5]
# scores [0.5131566]
# bboxes [[381 175 161 111]]
# classs [5 5]
# scores [0.86763924 0.8035498 ]
# bboxes [[382 180 170 107]
#  [387 178 159 112]]
# classs [5 5]
# scores [0.73400116 0.78263843]
# bboxes [[392 180 167 107]
#  [390 180 160 111]]
# classs [5 5 5]
# scores [0.9405541  0.8235606  0.74649817]
# bboxes [[386 182 186 111]
#  [387 181 172 112]
#  [396 183 177 109]]
# classs [6 5]
# scores [0.585714  0.6773057]
# bboxes [[217  85 361 217]
#  [390 179 185 112]]
# classs [5 5]
# scores [0.9376616 0.8643546]
# bboxes [[400 179 183 118]
#  [403 187 185 109]]
# classs [5 5]
# scores [0.90833896 0.8686062 ]
# bboxes [[402 181 181 116]
#  [405 188 181 109]]
# classs ()
# scores ()
# bboxes ()
# classs ()
# scores ()
# bboxes ()

# %% [markdown]
# ### conclusion:
# our pre trained yolo4 model working very well over traffic video to detact car trucks etc as shown above the output of video,their bbox ,class name, class id etc
